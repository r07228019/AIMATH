# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
rainfall = [68.5,
 177.0,
 207.0,
 29.5,
 32.0,
 31.0,
 28.0,
 71.0,
 32.0,
 72.0,
 35.5,
 30.5,
 25.5,
 59.0,
 43.5,
 29.5,
 11.0,
 14.0,
 22.5,
 17.0,
 17.0,
 25.0,
 27.5,
 117.0,
 15.5,
 21.5,
 20.5,
 122.5,
 27.5,
 21.0,
 144.5,
 45.5,
 12.5,
 37.0,
 40.5,
 66.5,
 26.0,
 20.5,
 20.5,
 24.5,
 31.5,
 21.0,
 49.0,
 24.0,
 25.0,
 52.0,
 30.0,
 27.5,
 27.0,
 22.5,
 32.5,
 15.0,
 21.5,
 36.0,
 20.5,
 23.0,
 29.5,
 76.0,
 36.5,
 14.5,
 19.0,
 19.5,
 25.0,
 104.5,
 25.5,
 34.0,
 67.5,
 49.5,
 14.5,
 19.5,
 21.0,
 46.0,
 25.0,
 24.5,
 27.5,
 92.0,
 55.0,
 25.0,
 69.5,
 37.0,
 23.0,
 25.5,
 35.5,
 37.0,
 16.0]

# %%
y = rainfall # 新北市三和雨量站降雨日雨量資料

plt.figure(figsize = (15, 7))
plt.plot(y, color = 'b', linestyle = 'dashed', alpha = 0.4, linewidth = 2)
plt.xlabel("Serial number of rainy days", fontsize = 'x-large')
plt.ylabel("Daily rainfall (mm)", fontsize = 'x-large')
plt.title("Daily rainfall", fontsize = 'xx-large')
# Out:
# Text(0.5,1,'Daily rainfall')

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from numpy import pi, cos, sin, e

t = np.linspace(0, 12 * pi, 10000)
x = sin(t) * (e ** (cos(t)) - 2 * cos(4 * t) - sin(t / 12) ** 5)
y = cos(t) * (e ** (cos(t)) - 2 * cos(4 * t) - sin(t / 12) ** 5)
plt.figure(figsize = (12, 8))
plt.plot(x, y, color = 'r', alpha = 0.5, linewidth = 1)
plt.xlabel("x", fontsize = 'x-large')
plt.ylabel("y", fontsize = 'x-large')
plt.title("Butterfly curve", fontsize = 'xx-large')
# Out:
# Text(0.5,1,'Butterfly curve')
